# %% [markdown]
# # Tackling the Health Crises in Africa
#
#
# ### by Gift Omodu

# %% [markdown]
# ### Data Overview
#
# The data consist of Africa health records from 1990 to 2019. These records includes: Causes of death, Number of death by age groups, Medical doctors per 10,000 population, Country codes, World population, Health expenditure(% of GDP).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

import squarify as sq

# %% [markdown]
# ## Assessing Data

# %%
def read_data(data):
    name = pd.read_csv(data)
    
    return name

# %%
def read_data2(data):
    name = pd.read_excel(data)
    
    return name

# %%
deaths_df = read_data("Final Datasets/1. annual-number-of-deaths-by-cause.csv")
deaths_df.sample(5)
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 2833     India  IND  1998                                          NaN
# 5418  Scotland  NaN  2018                                          NaN
# 990   Cambodia  KHM  2002                                          NaN
# 7169     Yemen  YEM  2011                                           41
# 3986    Monaco  MCO  1994                                          NaN
#
#       Meningitis  Alzheimer's disease and other dementias  \
# 2833     80366.0                                  33498.0
# 5418        25.0                                   2604.0
# 990        600.0                                    773.0
# 7169       537.0                                   1282.0
# 3986         0.0                                     19.0
#
#       Parkinson's disease  Nutritional deficiencies   Malaria  Drowning  ...  \
# 2833              18778.0                  154443.0  108147.0   79681.0  ...
# 5418                597.0                      18.0       0.0      31.0  ...
# 990                 200.0                    1552.0     633.0    1532.0  ...
# 7169                302.0                    1463.0    4057.0     858.0  ...
# 3986                  4.0                       0.0       0.0       1.0  ...
#
#       Chronic kidney disease  Poisonings   Protein  Terrorism (deaths)  \
# 2833                128993.0      6532.0  112329.0               398.0
# 5418                   807.0        15.0      13.0                 NaN
# 990                   1404.0        90.0    1446.0                 4.0
# 7169                  1997.0       417.0    1393.0               461.0
# 3986                     4.0         1.0       0.0                 NaN
#
#       Road injuries  Chronic respiratory diseases  \
# 2833       163005.0                      740139.0
# 5418          249.0                        5209.0
# 990          2775.0                        3295.0
# 7169         9969.0                        4539.0
# 3986            3.0                          16.0
#
#       Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 2833                                    183316.0            377646.0
# 5418                                      1217.0              3514.0
# 990                                       5961.0              9484.0
# 7169                                      2423.0              4194.0
# 3986                                         6.0                14.0
#
#       Fire, heat, and hot substances  Acute hepatitis
# 2833                         24595.0          64045.0
# 5418                            40.0              2.0
# 990                            247.0            198.0
# 7169                           780.0            570.0
# 3986                             0.0              0.0
#
# [5 rows x 36 columns]

# %%
deaths_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entity                                        7273 non-null   object
#  1   Code                                          6206 non-null   object
#  2   Year                                          7273 non-null   int64
#  3   Number of executions (Amnesty International)  267 non-null    object
#  4   Meningitis                                    6840 non-null   float64
#  5   Alzheimer's disease and other dementias       6840 non-null   float64
#  6   Parkinson's disease                           6840 non-null   float64
#  7   Nutritional deficiencies                      6840 non-null   float64
#  8   Malaria                                       6840 non-null   float64
#  9   Drowning                                      6840 non-null   float64
#  10  Interpersonal violence                        6840 non-null   float64
#  11  Maternal disorders                            6840 non-null   float64
#  12  HIV/AIDS                                      6840 non-null   float64
#  13  Drug use disorders                            6840 non-null   float64
#  14  Tuberculosis                                  6840 non-null   float64
#  15  Cardiovascular diseases                       6840 non-null   float64
#  16  Lower respiratory infections                  6840 non-null   float64
#  17  Neonatal disorders                            6840 non-null   float64
#  18  Alcohol use disorders                         6840 non-null   float64
#  19  Self                                          6840 non-null   float64
#  20  Exposure to forces of nature                  6840 non-null   float64
#  21  Diarrheal diseases                            6840 non-null   float64
#  22  Environmental heat and cold exposure          6840 non-null   float64
#  23  Neoplasms                                     6840 non-null   float64
#  24  Conflict and terrorism                        6840 non-null   float64
#  25  Diabetes mellitus                             6840 non-null   float64
#  26  Chronic kidney disease                        6840 non-null   float64
#  27  Poisonings                                    6840 non-null   float64
#  28  Protein                                       6840 non-null   float64
#  29  Terrorism (deaths)                            2891 non-null   float64
#  30  Road injuries                                 6840 non-null   float64
#  31  Chronic respiratory diseases                  6840 non-null   float64
#  32  Cirrhosis and other chronic liver diseases    6840 non-null   float64
#  33  Digestive diseases                            6840 non-null   float64
#  34  Fire, heat, and hot substances                6840 non-null   float64
#  35  Acute hepatitis                               6840 non-null   float64
# dtypes: float64(32), int64(1), object(3)
# memory usage: 2.0+ MB

# %%
deaths_df.isnull().sum()
# Out:
# Entity                                             0
# Code                                            1067
# Year                                               0
# Number of executions (Amnesty International)    7006
# Meningitis                                       433
# Alzheimer's disease and other dementias          433
# Parkinson's disease                              433
# Nutritional deficiencies                         433
# Malaria                                          433
# Drowning                                         433
# Interpersonal violence                           433
# Maternal disorders                               433
# HIV/AIDS                                         433
# Drug use disorders                               433
# Tuberculosis                                     433
# Cardiovascular diseases                          433
# Lower respiratory infections                     433
# Neonatal disorders                               433
# Alcohol use disorders                            433
# Self                                             433
# Exposure to forces of nature                     433
# Diarrheal diseases                               433
# Environmental heat and cold exposure             433
# Neoplasms                                        433
# Conflict and terrorism                           433
# Diabetes mellitus                                433
# Chronic kidney disease                           433
# Poisonings                                       433
# Protein                                          433
# Terrorism (deaths)                              4382
# Road injuries                                    433
# Chronic respiratory diseases                     433
# Cirrhosis and other chronic liver diseases       433
# Digestive diseases                               433
# Fire, heat, and hot substances                   433
# Acute hepatitis                                  433
# dtype: int64

# %%
deaths_df.duplicated().sum()
# Out:
# 0

# %%
deaths_df.describe()
# Out:
#               Year     Meningitis  Alzheimer's disease and other dementias  \
# count  7273.000000    6840.000000                             6.840000e+03
# mean   2004.425134    8213.149561                             2.736319e+04
# std       8.623572   34982.933895                             1.113146e+05
# min    1990.000000       0.000000                             0.000000e+00
# 25%    1997.000000      19.000000                             1.287500e+02
# 50%    2004.000000     150.500000                             8.455000e+02
# 75%    2012.000000    1622.250000                             4.251000e+03
# max    2019.000000  432524.000000                             1.623276e+06
#
#        Parkinson's disease  Nutritional deficiencies        Malaria  \
# count          6840.000000               6840.000000    6840.000000
# mean           6493.627339              11006.353947   18903.160234
# std           25767.447063              48289.687100   97346.780570
# min               0.000000                  0.000000       0.000000
# 25%              37.000000                 11.000000       0.000000
# 50%             209.000000                159.000000       0.000000
# 75%             984.000000               2204.000000    1017.250000
# max          362907.000000             757152.000000  961129.000000
#
#             Drowning  Interpersonal violence  Maternal disorders  \
# count    6840.000000             6840.000000         6840.000000
# mean     8619.055117            10636.648684         6131.066959
# std     35879.406010            40888.793762        26355.210370
# min         0.000000                0.000000            0.000000
# 25%        39.000000               48.000000            6.000000
# 50%       253.000000              342.000000           70.500000
# 75%      1014.250000             1391.250000         1244.500000
# max    460665.000000           463129.000000       302586.000000
#
#            HIV/AIDS  ...  Chronic kidney disease    Poisonings        Protein  \
# count  6.840000e+03  ...            6.840000e+03   6840.000000    6840.000000
# mean   2.814125e+04  ...            2.506893e+04   2145.455848    9531.528801
# std    1.391973e+05  ...            9.600839e+04   8433.507625   41689.675155
# min    0.000000e+00  ...            0.000000e+00      0.000000       0.000000
# 25%    1.400000e+01  ...            2.140000e+02      8.000000       6.000000
# 50%    1.870000e+02  ...            1.080000e+03     72.000000     120.000000
# 75%    3.836500e+03  ...            4.497500e+03    371.000000    2120.000000
# max    1.844490e+06  ...            1.427232e+06  92101.000000  656314.000000
#
#        Terrorism (deaths)  Road injuries  Chronic respiratory diseases  \
# count         2891.000000   6.840000e+03                  6.840000e+03
# mean           349.235905   3.063496e+04                  9.130390e+04
# std           1917.143788   1.166999e+05                  3.772013e+05
# min              0.000000   0.000000e+00                  1.000000e+00
# 25%              0.000000   2.077500e+02                  3.685000e+02
# 50%              5.000000   1.239500e+03                  2.104000e+03
# 75%             60.000000   5.786250e+03                  9.013250e+03
# max          44490.000000   1.285039e+06                  3.974315e+06
#
#        Cirrhosis and other chronic liver diseases  Digestive diseases  \
# count                                6.840000e+03        6.840000e+03
# mean                                 3.189892e+04        5.652551e+04
# std                                  1.194387e+05        2.109884e+05
# min                                  0.000000e+00        0.000000e+00
# 25%                                  2.047500e+02        4.000000e+02
# 50%                                  1.541000e+03        2.778500e+03
# 75%                                  5.670500e+03        9.594000e+03
# max                                  1.472012e+06        2.557689e+06
#
#        Fire, heat, and hot substances  Acute hepatitis
# count                     6840.000000      6840.000000
# mean                      3006.043275      3112.066520
# std                      11211.885249     14440.219516
# min                          0.000000         0.000000
# 25%                         21.000000         2.000000
# 50%                        152.000000        21.500000
# 75%                        593.250000       264.000000
# max                     129705.000000    166405.000000
#
# [8 rows x 33 columns]

# %%
age_df = read_data("Final Datasets/2. number-of-deaths-by-age-group.csv")
age_df.sample(5)
# Out:
#                      Entity Code  Year  Deaths 70+ years  Deaths 50-69 years  \
# 4841                Romania  ROU  2001            146873               80159
# 5464        South Asia (WB)  NaN  1994           2375259             2543169
# 6678  World Bank Low Income  NaN  2008            871254              890549
# 1407                   Cuba  CUB  2017             69895               27916
# 2521                  Haiti  HTI  1991             13844               17156
#
#       Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 4841                    25901               1404            4716
# 5464                  1896649             514688         3725290
# 6678                  1113577             193943         2232180
# 1407                     6942                223             606
# 2521                    15521               2873           35699

# %%
age_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   6840 non-null   object
#  1   Code                     6150 non-null   object
#  2   Year                     6840 non-null   int64
#  3   Deaths 70+ years         6840 non-null   int64
#  4   Deaths 50-69 years       6840 non-null   int64
#  5   Deaths Age: 15-49 years  6840 non-null   int64
#  6   Deaths 5-14 years        6840 non-null   int64
#  7   Deaths Under 5           6840 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 427.6+ KB

# %%
age_df.describe()
# Out:
#               Year  Deaths 70+ years  Deaths 50-69 years  \
# count  6840.000000      6.840000e+03        6.840000e+03
# mean   2004.500000      5.674685e+05        3.253844e+05
# std       8.656074      2.196604e+06        1.242145e+06
# min    1990.000000      5.000000e+00        3.000000e+00
# 25%    1997.000000      3.668750e+03        2.927000e+03
# 50%    2004.500000      2.141700e+04        1.428650e+04
# 75%    2012.000000      8.464750e+04        5.242625e+04
# max    2019.000000      2.840781e+07        1.496755e+07
#
#        Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# count             6.840000e+03       6.840000e+03    6.840000e+03
# mean              2.003344e+05       2.451118e+04    2.021524e+05
# std               7.598624e+05       1.016780e+05    8.520685e+05
# min               1.000000e+00       0.000000e+00    0.000000e+00
# 25%               1.697000e+03       7.900000e+01    3.650000e+02
# 50%               8.815000e+03       6.065000e+02    3.487000e+03
# 75%               3.652850e+04       5.349500e+03    4.441825e+04
# max               8.878754e+06       1.308749e+06    1.198120e+07

# %%
age_df.isnull().sum()
# Out:
# Entity                       0
# Code                       690
# Year                         0
# Deaths 70+ years             0
# Deaths 50-69 years           0
# Deaths Age: 15-49 years      0
# Deaths 5-14 years            0
# Deaths Under 5               0
# dtype: int64

# %%
age_df.duplicated().sum()
# Out:
# 0

# %%
age_df.nunique()
# Out:
# Entity                      228
# Code                        205
# Year                         30
# Deaths 70+ years           6101
# Deaths 50-69 years         5894
# Deaths Age: 15-49 years    5623
# Deaths 5-14 years          3524
# Deaths Under 5             4886
# dtype: int64

# %%
country_code= read_data("Final Datasets/4. ISO 3166_country-and-continent-codes-list-csv.csv")
country_code.sample(5)
# Out:
#     Continent_Name Continent_Code             Country_Name  \
# 158        Oceania             OC              New Zealand
# 147         Africa             AF     Namibia, Republic of
# 8             Asia             AS  Azerbaijan, Republic of
# 200         Africa             AF  Seychelles, Republic of
# 169        Oceania             OC       Palau, Republic of
#
#     Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 158                      NZ                       NZL           554.0
# 147                     NaN                       NAM           516.0
# 8                        AZ                       AZE            31.0
# 200                      SC                       SYC           690.0
# 169                      PW                       PLW           585.0

# %%
country_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Continent_Name             254 non-null    object
#  1   Continent_Code             212 non-null    object
#  2   Country_Name               254 non-null    object
#  3   Two_Letter_Country_Code    253 non-null    object
#  4   Three_Letter_Country_Code  254 non-null    object
#  5   Country_Number             250 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 12.0+ KB

# %%
country_code.isnull().sum()
# Out:
# Continent_Name                0
# Continent_Code               42
# Country_Name                  0
# Two_Letter_Country_Code       1
# Three_Letter_Country_Code     0
# Country_Number                4
# dtype: int64

# %%
country_code.duplicated().sum()
# Out:
# 0

# %%
afr_country = country_code.query('Continent_Code == "AF"')
afr_country.count()
# Out:
# Continent_Name               58
# Continent_Code               58
# Country_Name                 58
# Two_Letter_Country_Code      57
# Three_Letter_Country_Code    58
# Country_Number               58
# dtype: int64

# %%
afr_country.nunique()
# Out:
# Continent_Name                1
# Continent_Code                1
# Country_Name                 58
# Two_Letter_Country_Code      57
# Three_Letter_Country_Code    58
# Country_Number               58
# dtype: int64

# %%
world_ppl = read_data("Final Datasets/5. World Population.csv")
world_ppl.sample(5)
# Out:
#                   Entity Code  Year  Population (historical estimates)
# 39865               Peru  PER  1931                            5642656
# 14988  Equatorial Guinea  GNQ   400                              29096
# 32982           Mongolia  MNG  1760                             606720
# 40357             Poland  POL  1905                           25221471
# 9959               Chile  CHL  1720                             634113

# %%
world_ppl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56913 entries, 0 to 56912
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Entity                             56913 non-null  object
#  1   Code                               54251 non-null  object
#  2   Year                               56913 non-null  int64
#  3   Population (historical estimates)  56913 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 1.7+ MB

# %%
world_ppl.duplicated().sum()
# Out:
# 0

# %%
world_ppl.isnull().sum()
# Out:
# Entity                                  0
# Code                                 2662
# Year                                    0
# Population (historical estimates)       0
# dtype: int64

# %%
doctors_df = read_data2("Final Datasets/3. Medical Doctors Per 10000 population.xlsx")
doctors_df.sample(5)
# Out:
#       IndicatorCode                                     Indicator  \
# 10405      HWF_0005  Medical doctors not further defined (number)
# 11133      HWF_0005  Medical doctors not further defined (number)
# 4043       HWF_0002                      Medical doctors (number)
# 3765       HWF_0002                      Medical doctors (number)
# 2952       HWF_0002                      Medical doctors (number)
#
#       ParentLocationCode         ParentLocation ThreeLocCode   Location  \
# 10405                EUR                 Europe          ISL    Iceland
# 11133                WPR        Western Pacific          AUS  Australia
# 4043                 EUR                 Europe          BEL    Belgium
# 3765                 EMR  Eastern Mediterranean          MAR    Morocco
# 2952                 AFR                 Africa          ERI    Eritrea
#
#        Period  FactValueNumeric   Value
# 10405    1981             509.0     509
# 11133    2010           74061.0  74 061
# 4043     2009           31578.0  31 578
# 3765     2007           18269.0  18 269
# 2952     2012             153.0     153

# %%
doctors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11508 entries, 0 to 11507
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   IndicatorCode       11508 non-null  object
#  1   Indicator           11508 non-null  object
#  2   ParentLocationCode  11508 non-null  object
#  3   ParentLocation      11508 non-null  object
#  4   ThreeLocCode        11508 non-null  object
#  5   Location            11508 non-null  object
#  6   Period              11508 non-null  int64
#  7   FactValueNumeric    11508 non-null  float64
#  8   Value               11508 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 809.3+ KB

# %%
doctors_df.duplicated().sum()
# Out:
# 0

# %%
doctors_df.isnull().sum()
# Out:
# IndicatorCode         0
# Indicator             0
# ParentLocationCode    0
# ParentLocation        0
# ThreeLocCode          0
# Location              0
# Period                0
# FactValueNumeric      0
# Value                 0
# dtype: int64

# %%
afr_doctors = doctors_df.query('ParentLocationCode == "AFR"')
afr_doctors.count()
# Out:
# IndicatorCode         1356
# Indicator             1356
# ParentLocationCode    1356
# ParentLocation        1356
# ThreeLocCode          1356
# Location              1356
# Period                1356
# FactValueNumeric      1356
# Value                 1356
# dtype: int64

# %%
che_df = read_data2("Final Datasets/6. Current health expenditure (% of GDP).xlsx")
che_df.sample(5)
# Out:
#                                           Country Name Country Code  \
# 173                                              Niger          NER
# 33                                            Botswana          BWA
# 193                          Korea, Dem. People's Rep.          PRK
# 238  Middle East & North Africa (IDA & IBRD countries)          TMN
# 93                                                Guam          GUM
#
#                             Indicator Name      2000      2001      2002  \
# 173  Current health expenditure (% of GDP)  4.690062  4.758148  4.858969
# 33   Current health expenditure (% of GDP)  5.827264  6.156716  6.421541
# 193  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 238  Current health expenditure (% of GDP)  4.722069  5.110720  5.006814
# 93   Current health expenditure (% of GDP)       NaN       NaN       NaN
#
#          2003      2004      2005      2006  ...      2012      2013  \
# 173  4.779541  5.011175  5.676366  5.808914  ...  4.307322  4.466359
# 33   6.176169  5.795304  5.025351  4.773733  ...  6.141460  6.224388
# 193       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 238  5.005821  4.785709  4.574040  4.467004  ...  5.552704  5.314752
# 93        NaN       NaN       NaN       NaN  ...       NaN       NaN
#
#          2014      2015      2016      2017      2018      2019  2020  2021
# 173  4.453768  5.347462  4.532391  5.574114  5.288451  5.668631   NaN   NaN
# 33   5.597931  5.726299  5.560522  6.134534  5.968672  6.048366   NaN   NaN
# 193       NaN       NaN       NaN       NaN       NaN       NaN   NaN   NaN
# 238  5.638847  6.055631  6.537005  6.694655  6.281415  5.732079   NaN   NaN
# 93        NaN       NaN       NaN       NaN       NaN       NaN   NaN   NaN
#
# [5 rows x 25 columns]

# %%
che_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   2000            232 non-null    float64
#  4   2001            232 non-null    float64
#  5   2002            233 non-null    float64
#  6   2003            235 non-null    float64
#  7   2004            235 non-null    float64
#  8   2005            235 non-null    float64
#  9   2006            235 non-null    float64
#  10  2007            235 non-null    float64
#  11  2008            235 non-null    float64
#  12  2009            235 non-null    float64
#  13  2010            236 non-null    float64
#  14  2011            237 non-null    float64
#  15  2012            236 non-null    float64
#  16  2013            235 non-null    float64
#  17  2014            235 non-null    float64
#  18  2015            235 non-null    float64
#  19  2016            234 non-null    float64
#  20  2017            235 non-null    float64
#  21  2018            235 non-null    float64
#  22  2019            234 non-null    float64
#  23  2020            0 non-null      float64
#  24  2021            0 non-null      float64
# dtypes: float64(22), object(3)
# memory usage: 52.1+ KB

# %%
che_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## CLEANING THROUGH DATA SETS

# %% [markdown]
# ### African Country Names Data : "afr_country"
#
# #### Define:
#
#        1. Rename column "Three+Letter_Country_Code" to "Code"
#        2. Drop column "Two_Letter_Country_Code
#        3. Extract country names from the "Country_Name" column

# %% [markdown]
# #### Code:

# %%
afr_country.rename(columns= {"Three_Letter_Country_Code" : "Code"}, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\4049029065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_country.rename(columns= {"Three_Letter_Country_Code" : "Code"}, inplace=True)

# %%
afr_country.drop(columns= "Two_Letter_Country_Code", axis =1, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\3086410313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_country.drop(columns= "Two_Letter_Country_Code", axis =1, inplace=True)

# %%
afr_country["Country_Name"] = afr_country['Country_Name'].str.split(",").str[0]
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\3693049461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_country["Country_Name"] = afr_country['Country_Name'].str.split(",").str[0]

# %% [markdown]
# #### Test:

# %%
afr_country.sample(5)
# Out:
#     Continent_Name Continent_Code           Country_Name Code  Country_Number
# 183         Africa             AF                Reunion  REU           638.0
# 121         Africa             AF                Lesotho  LSO           426.0
# 130         Africa             AF                 Malawi  MWI           454.0
# 133         Africa             AF                   Mali  MLI           466.0
# 196         Africa             AF  Sao Tome and Principe  STP           678.0

# %%
afr_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 3 to 249
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Continent_Name  58 non-null     object
#  1   Continent_Code  58 non-null     object
#  2   Country_Name    58 non-null     object
#  3   Code            58 non-null     object
#  4   Country_Number  58 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.7+ KB

# %%
afr_country["Code"].nunique()
# Out:
# 58

# %%
afr_country.drop('Country_Number', axis=1, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\33610126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_country.drop('Country_Number', axis=1, inplace=True)

# %%
afr_country.drop(columns=["Continent_Name", "Continent_Code"], axis=1, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\2052399133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_country.drop(columns=["Continent_Name", "Continent_Code"], axis=1, inplace=True)

# %%
afr_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 3 to 249
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country_Name  58 non-null     object
#  1   Code          58 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
afr_df= afr_country

# %%
df1 = afr_df.merge(deaths_df, on ='Code', how="inner")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1622 entries, 0 to 1621
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country_Name                                  1622 non-null   object
#  1   Code                                          1622 non-null   object
#  2   Entity                                        1622 non-null   object
#  3   Year                                          1622 non-null   int64
#  4   Number of executions (Amnesty International)  64 non-null     object
#  5   Meningitis                                    1620 non-null   float64
#  6   Alzheimer's disease and other dementias       1620 non-null   float64
#  7   Parkinson's disease                           1620 non-null   float64
#  8   Nutritional deficiencies                      1620 non-null   float64
#  9   Malaria                                       1620 non-null   float64
#  10  Drowning                                      1620 non-null   float64
#  11  Interpersonal violence                        1620 non-null   float64
#  12  Maternal disorders                            1620 non-null   float64
#  13  HIV/AIDS                                      1620 non-null   float64
#  14  Drug use disorders                            1620 non-null   float64
#  15  Tuberculosis                                  1620 non-null   float64
#  16  Cardiovascular diseases                       1620 non-null   float64
#  17  Lower respiratory infections                  1620 non-null   float64
#  18  Neonatal disorders                            1620 non-null   float64
#  19  Alcohol use disorders                         1620 non-null   float64
#  20  Self                                          1620 non-null   float64
#  21  Exposure to forces of nature                  1620 non-null   float64
#  22  Diarrheal diseases                            1620 non-null   float64
#  23  Environmental heat and cold exposure          1620 non-null   float64
#  24  Neoplasms                                     1620 non-null   float64
#  25  Conflict and terrorism                        1620 non-null   float64
#  26  Diabetes mellitus                             1620 non-null   float64
#  27  Chronic kidney disease                        1620 non-null   float64
#  28  Poisonings                                    1620 non-null   float64
#  29  Protein                                       1620 non-null   float64
#  30  Terrorism (deaths)                            670 non-null    float64
#  31  Road injuries                                 1620 non-null   float64
#  32  Chronic respiratory diseases                  1620 non-null   float64
#  33  Cirrhosis and other chronic liver diseases    1620 non-null   float64
#  34  Digestive diseases                            1620 non-null   float64
#  35  Fire, heat, and hot substances                1620 non-null   float64
#  36  Acute hepatitis                               1620 non-null   float64
# dtypes: float64(32), int64(1), object(4)
# memory usage: 481.5+ KB

# %%
df1.isnull().sum()
# Out:
# Country_Name                                       0
# Code                                               0
# Entity                                             0
# Year                                               0
# Number of executions (Amnesty International)    1558
# Meningitis                                         2
# Alzheimer's disease and other dementias            2
# Parkinson's disease                                2
# Nutritional deficiencies                           2
# Malaria                                            2
# Drowning                                           2
# Interpersonal violence                             2
# Maternal disorders                                 2
# HIV/AIDS                                           2
# Drug use disorders                                 2
# Tuberculosis                                       2
# Cardiovascular diseases                            2
# Lower respiratory infections                       2
# Neonatal disorders                                 2
# Alcohol use disorders                              2
# Self                                               2
# Exposure to forces of nature                       2
# Diarrheal diseases                                 2
# Environmental heat and cold exposure               2
# Neoplasms                                          2
# Conflict and terrorism                             2
# Diabetes mellitus                                  2
# Chronic kidney disease                             2
# Poisonings                                         2
# Protein                                            2
# Terrorism (deaths)                               952
# Road injuries                                      2
# Chronic respiratory diseases                       2
# Cirrhosis and other chronic liver diseases         2
# Digestive diseases                                 2
# Fire, heat, and hot substances                     2
# Acute hepatitis                                    2
# dtype: int64

# %%
df1.drop(columns=['Entity','Code'], axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1622 entries, 0 to 1621
# Data columns (total 35 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Country_Name                                  1622 non-null   object
#  1   Year                                          1622 non-null   int64
#  2   Number of executions (Amnesty International)  64 non-null     object
#  3   Meningitis                                    1620 non-null   float64
#  4   Alzheimer's disease and other dementias       1620 non-null   float64
#  5   Parkinson's disease                           1620 non-null   float64
#  6   Nutritional deficiencies                      1620 non-null   float64
#  7   Malaria                                       1620 non-null   float64
#  8   Drowning                                      1620 non-null   float64
#  9   Interpersonal violence                        1620 non-null   float64
#  10  Maternal disorders                            1620 non-null   float64
#  11  HIV/AIDS                                      1620 non-null   float64
#  12  Drug use disorders                            1620 non-null   float64
#  13  Tuberculosis                                  1620 non-null   float64
#  14  Cardiovascular diseases                       1620 non-null   float64
#  15  Lower respiratory infections                  1620 non-null   float64
#  16  Neonatal disorders                            1620 non-null   float64
#  17  Alcohol use disorders                         1620 non-null   float64
#  18  Self                                          1620 non-null   float64
#  19  Exposure to forces of nature                  1620 non-null   float64
#  20  Diarrheal diseases                            1620 non-null   float64
#  21  Environmental heat and cold exposure          1620 non-null   float64
#  22  Neoplasms                                     1620 non-null   float64
#  23  Conflict and terrorism                        1620 non-null   float64
#  24  Diabetes mellitus                             1620 non-null   float64
#  25  Chronic kidney disease                        1620 non-null   float64
#  26  Poisonings                                    1620 non-null   float64
#  27  Protein                                       1620 non-null   float64
#  28  Terrorism (deaths)                            670 non-null    float64
#  29  Road injuries                                 1620 non-null   float64
#  30  Chronic respiratory diseases                  1620 non-null   float64
#  31  Cirrhosis and other chronic liver diseases    1620 non-null   float64
#  32  Digestive diseases                            1620 non-null   float64
#  33  Fire, heat, and hot substances                1620 non-null   float64
#  34  Acute hepatitis                               1620 non-null   float64
# dtypes: float64(32), int64(1), object(2)
# memory usage: 456.2+ KB

# %%
df1.isnull().sum()
# Out:
# Country_Name                                       0
# Year                                               0
# Number of executions (Amnesty International)    1558
# Meningitis                                         2
# Alzheimer's disease and other dementias            2
# Parkinson's disease                                2
# Nutritional deficiencies                           2
# Malaria                                            2
# Drowning                                           2
# Interpersonal violence                             2
# Maternal disorders                                 2
# HIV/AIDS                                           2
# Drug use disorders                                 2
# Tuberculosis                                       2
# Cardiovascular diseases                            2
# Lower respiratory infections                       2
# Neonatal disorders                                 2
# Alcohol use disorders                              2
# Self                                               2
# Exposure to forces of nature                       2
# Diarrheal diseases                                 2
# Environmental heat and cold exposure               2
# Neoplasms                                          2
# Conflict and terrorism                             2
# Diabetes mellitus                                  2
# Chronic kidney disease                             2
# Poisonings                                         2
# Protein                                            2
# Terrorism (deaths)                               952
# Road injuries                                      2
# Chronic respiratory diseases                       2
# Cirrhosis and other chronic liver diseases         2
# Digestive diseases                                 2
# Fire, heat, and hot substances                     2
# Acute hepatitis                                    2
# dtype: int64

# %%
df1['Country_Name'].isnull().sum()
# Out:
# 0

# %%
df1.fillna(0)
# Out:
#      Country_Name  Year Number of executions (Amnesty International)  \
# 0         Algeria  1990                                            0
# 1         Algeria  1991                                            0
# 2         Algeria  1992                                            0
# 3         Algeria  1993                                            0
# 4         Algeria  1994                                            0
# ...           ...   ...                                          ...
# 1617       Zambia  2015                                            0
# 1618       Zambia  2016                                            0
# 1619       Zambia  2017                                            0
# 1620       Zambia  2018                                            0
# 1621       Zambia  2019                                            0
#
#       Meningitis  Alzheimer's disease and other dementias  \
# 0          838.0                                   1337.0
# 1          794.0                                   1411.0
# 2          763.0                                   1494.0
# 3          736.0                                   1582.0
# 4          708.0                                   1675.0
# ...          ...                                      ...
# 1617      2256.0                                    626.0
# 1618      2174.0                                    651.0
# 1619      2156.0                                    689.0
# 1620      2088.0                                    726.0
# 1621      2065.0                                    763.0
#
#       Parkinson's disease  Nutritional deficiencies  Malaria  Drowning  \
# 0                   439.0                     453.0      9.0    1207.0
# 1                   451.0                     439.0      9.0    1136.0
# 2                   470.0                     427.0     12.0    1111.0
# 3                   488.0                     417.0     12.0    1092.0
# 4                   509.0                     402.0      8.0    1086.0
# ...                   ...                       ...      ...       ...
# 1617                173.0                    2269.0   5235.0     406.0
# 1618                178.0                    2148.0   4716.0     391.0
# 1619                186.0                    2087.0   4287.0     386.0
# 1620                195.0                    1954.0   4815.0     366.0
# 1621                203.0                    1899.0   4777.0     359.0
#
#       Interpersonal violence  ...  Chronic kidney disease  Poisonings  \
# 0                      491.0  ...                  3559.0       485.0
# 1                      484.0  ...                  3640.0       469.0
# 2                      497.0  ...                  3687.0       464.0
# 3                      513.0  ...                  3741.0       461.0
# 4                      553.0  ...                  3806.0       460.0
# ...                      ...  ...                     ...         ...
# 1617                  1428.0  ...                  1703.0       305.0
# 1618                  1490.0  ...                  1746.0       304.0
# 1619                  1531.0  ...                  1813.0       307.0
# 1620                  1577.0  ...                  1870.0       306.0
# 1621                  1616.0  ...                  1931.0       309.0
#
#       Protein  Terrorism (deaths)  Road injuries  \
# 0       422.0                 3.0        13438.0
# 1       408.0                42.0        13120.0
# 2       396.0               236.0        13115.0
# 3       386.0                 0.0        13154.0
# 4       370.0               500.0        13326.0
# ...       ...                 ...            ...
# 1617   2199.0                 0.0         2173.0
# 1618   2078.0                 0.0         2209.0
# 1619   2016.0                 0.0         2252.0
# 1620   1884.0                 0.0         2258.0
# 1621   1828.0                 0.0         2285.0
#
#       Chronic respiratory diseases  \
# 0                           4410.0
# 1                           4481.0
# 2                           4571.0
# 3                           4668.0
# 4                           4773.0
# ...                            ...
# 1617                        2214.0
# 1618                        2249.0
# 1619                        2302.0
# 1620                        2341.0
# 1621                        2388.0
#
#       Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                         2401.0              3981.0
# 1                                         2456.0              4033.0
# 2                                         2500.0              4083.0
# 3                                         2542.0              4136.0
# 4                                         2588.0              4193.0
# ...                                          ...                 ...
# 1617                                      4026.0              5804.0
# 1618                                      4179.0              6000.0
# 1619                                      4386.0              6275.0
# 1620                                      4481.0              6385.0
# 1621                                      4593.0              6528.0
#
#       Fire, heat, and hot substances  Acute hepatitis
# 0                             1113.0            486.0
# 1                             1078.0            478.0
# 2                             1071.0            472.0
# 3                             1067.0            470.0
# 4                             1095.0            469.0
# ...                              ...              ...
# 1617                           326.0            270.0
# 1618                           323.0            268.0
# 1619                           325.0            270.0
# 1620                           323.0            265.0
# 1621                           326.0            263.0
#
# [1622 rows x 35 columns]

# %%
afr_dt = df1.copy()

# %%
afr_dt.isnull().sum()
# Out:
# Country_Name                                       0
# Year                                               0
# Number of executions (Amnesty International)    1558
# Meningitis                                         2
# Alzheimer's disease and other dementias            2
# Parkinson's disease                                2
# Nutritional deficiencies                           2
# Malaria                                            2
# Drowning                                           2
# Interpersonal violence                             2
# Maternal disorders                                 2
# HIV/AIDS                                           2
# Drug use disorders                                 2
# Tuberculosis                                       2
# Cardiovascular diseases                            2
# Lower respiratory infections                       2
# Neonatal disorders                                 2
# Alcohol use disorders                              2
# Self                                               2
# Exposure to forces of nature                       2
# Diarrheal diseases                                 2
# Environmental heat and cold exposure               2
# Neoplasms                                          2
# Conflict and terrorism                             2
# Diabetes mellitus                                  2
# Chronic kidney disease                             2
# Poisonings                                         2
# Protein                                            2
# Terrorism (deaths)                               952
# Road injuries                                      2
# Chronic respiratory diseases                       2
# Cirrhosis and other chronic liver diseases         2
# Digestive diseases                                 2
# Fire, heat, and hot substances                     2
# Acute hepatitis                                    2
# dtype: int64

# %%
afr_dt.fillna(0, inplace=True)

# %%
afr_dt.isnull().sum()
# Out:
# Country_Name                                    0
# Year                                            0
# Number of executions (Amnesty International)    0
# Meningitis                                      0
# Alzheimer's disease and other dementias         0
# Parkinson's disease                             0
# Nutritional deficiencies                        0
# Malaria                                         0
# Drowning                                        0
# Interpersonal violence                          0
# Maternal disorders                              0
# HIV/AIDS                                        0
# Drug use disorders                              0
# Tuberculosis                                    0
# Cardiovascular diseases                         0
# Lower respiratory infections                    0
# Neonatal disorders                              0
# Alcohol use disorders                           0
# Self                                            0
# Exposure to forces of nature                    0
# Diarrheal diseases                              0
# Environmental heat and cold exposure            0
# Neoplasms                                       0
# Conflict and terrorism                          0
# Diabetes mellitus                               0
# Chronic kidney disease                          0
# Poisonings                                      0
# Protein                                         0
# Terrorism (deaths)                              0
# Road injuries                                   0
# Chronic respiratory diseases                    0
# Cirrhosis and other chronic liver diseases      0
# Digestive diseases                              0
# Fire, heat, and hot substances                  0
# Acute hepatitis                                 0
# dtype: int64

# %%
afr_age = afr_df.merge(age_df, on="Code", how="inner")

# %%
afr_age.drop("Entity", axis=1, inplace=True)

# %%
afr_age.drop("Code", axis=1, inplace=True)

# %%
afr_age.tail()
# Out:
#      Country_Name  Year  Deaths 70+ years  Deaths 50-69 years  \
# 1615       Zambia  2015             20828               24196
# 1616       Zambia  2016             21403               24892
# 1617       Zambia  2017             22112               25745
# 1618       Zambia  2018             22784               26416
# 1619       Zambia  2019             23410               27051
#
#       Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 1615                    38387               5240           35951
# 1616                    38213               4846           34998
# 1617                    38420               4681           33892
# 1618                    37830               4370           32543
# 1619                    37212               4192           31490

# %%
afr_ppl = afr_df.merge(world_ppl, on= "Code", how="inner")

# %%
afr_ppl.drop(columns=["Entity", "Code"], axis=1, inplace=True)

# %%
afr_ppl.head(0)
# Out:
# Empty DataFrame
# Columns: [Country_Name, Year, Population (historical estimates)]
# Index: []

# %%
afr_ppl.rename(columns={"Population (historical estimates)": "Population"}, inplace=True)

# %%
afr_pop = afr_ppl.query("Year > 1989")

# %%
afr_pop.sample(5)
# Out:
#                 Country_Name  Year  Population
# 9768            Saint Helena  2010        5338
# 9332           Guinea-Bissau  2004     1347012
# 10014  Sao Tome and Principe  1997      137672
# 7017                  Malawi  1993    10257232
# 4700                  Gambia  2007     1764889

# %%
afr_doctors.drop(columns=["IndicatorCode","Indicator","ParentLocationCode","ParentLocation"], axis=1, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\1591588270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_doctors.drop(columns=["IndicatorCode","Indicator","ParentLocationCode","ParentLocation"], axis=1, inplace=True)

# %%
afr_doctors.drop(columns=["ThreeLocCode", "Value"], axis=1, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\726032145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_doctors.drop(columns=["ThreeLocCode", "Value"], axis=1, inplace=True)

# %%
afr_doctors.rename(columns={'FactValueNumeric' : 'Value'}, inplace=True)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\2941226439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   afr_doctors.rename(columns={'FactValueNumeric' : 'Value'}, inplace=True)

# %%
afr_doctors.sample(4)
# Out:
#        Location  Period    Value
# 9003       Chad    2014   608.00
# 8973    Senegal    2015  3023.00
# 247   Mauritius    2020    27.13
# 3038    Liberia    2009    90.00

# %%
che_df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name      2000      2001      2002  \
# 0  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 1  Current health expenditure (% of GDP)  6.252428  6.390627  5.969416
# 2  Current health expenditure (% of GDP)       NaN       NaN  9.443390
# 3  Current health expenditure (% of GDP)  3.771302  3.770256  3.387634
# 4  Current health expenditure (% of GDP)  1.908599  4.483516  3.329461
#
#        2003      2004      2005       2006  ...      2012      2013      2014  \
# 0       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 1  6.635666  6.710734  6.528098   6.492506  ...  6.562794  6.565689  6.152063
# 2  8.941258  9.808474  9.948290  10.622766  ...  7.897176  8.805941  9.528871
# 3  4.681099  4.481882  4.277262   4.139578  ...  3.505065  3.621925  3.614749
# 4  3.547973  3.967201  2.852197   2.685537  ...  2.395750  2.732828  2.434129
#
#         2015       2016       2017       2018       2019  2020  2021
# 0        NaN        NaN        NaN        NaN        NaN   NaN   NaN
# 1   6.482263   6.390654   6.317654   6.286829   6.266386   NaN   NaN
# 2  10.105348  11.818562  12.620817  14.126743  13.242202   NaN   NaN
# 3   3.834676   3.811248   3.789624   3.393160   3.366100   NaN   NaN
# 4   2.605795   2.713149   2.791503   2.540102   2.533360   NaN   NaN
#
# [5 rows x 25 columns]

# %%
che_df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# 2000               34
# 2001               34
# 2002               33
# 2003               31
# 2004               31
# 2005               31
# 2006               31
# 2007               31
# 2008               31
# 2009               31
# 2010               30
# 2011               29
# 2012               30
# 2013               31
# 2014               31
# 2015               31
# 2016               32
# 2017               31
# 2018               31
# 2019               32
# 2020              266
# 2021              266
# dtype: int64

# %%
che_df.drop(columns=[2020, 2021], axis=1, inplace=True)

# %%
che_df.fillna(0, inplace=True)

# %%
che_df.rename(columns={'Country Code': 'Code'}, inplace=True)

# %%
che_df.head()
# Out:
#                   Country Name Code                         Indicator Name  \
# 0                        Aruba  ABW  Current health expenditure (% of GDP)
# 1  Africa Eastern and Southern  AFE  Current health expenditure (% of GDP)
# 2                  Afghanistan  AFG  Current health expenditure (% of GDP)
# 3   Africa Western and Central  AFW  Current health expenditure (% of GDP)
# 4                       Angola  AGO  Current health expenditure (% of GDP)
#
#        2000      2001      2002      2003      2004      2005       2006  ...  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  ...
# 1  6.252428  6.390627  5.969416  6.635666  6.710734  6.528098   6.492506  ...
# 2  0.000000  0.000000  9.443390  8.941258  9.808474  9.948290  10.622766  ...
# 3  3.771302  3.770256  3.387634  4.681099  4.481882  4.277262   4.139578  ...
# 4  1.908599  4.483516  3.329461  3.547973  3.967201  2.852197   2.685537  ...
#
#        2010      2011      2012      2013      2014       2015       2016  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 1  6.922891  6.773979  6.562794  6.565689  6.152063   6.482263   6.390654
# 2  8.569672  8.561907  7.897176  8.805941  9.528871  10.105348  11.818562
# 3  3.521739  3.550677  3.505065  3.621925  3.614749   3.834676   3.811248
# 4  2.695100  2.645608  2.395750  2.732828  2.434129   2.605795   2.713149
#
#         2017       2018       2019
# 0   0.000000   0.000000   0.000000
# 1   6.317654   6.286829   6.266386
# 2  12.620817  14.126743  13.242202
# 3   3.789624   3.393160   3.366100
# 4   2.791503   2.540102   2.533360
#
# [5 rows x 23 columns]

# %%
che_df[che_df.Code == 'COD']
# Out:
#         Country Name Code                         Indicator Name    2000  \
# 43  Congo, Dem. Rep.  COD  Current health expenditure (% of GDP)  1.5504
#
#        2001      2002      2003     2004      2005      2006  ...      2010  \
# 43  2.70775  2.654775  3.818179  4.42029  4.252656  4.393809  ...  3.860356
#
#         2011      2012      2013     2014      2015      2016      2017  \
# 43  3.262672  3.300994  3.566633  3.97874  3.969213  4.366031  4.156466
#
#         2018      2019
# 43  3.302493  3.536261
#
# [1 rows x 23 columns]

# %%
afr_che = afr_country.merge(che_df, on ="Code", how="left")

# %%
afr_che.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 57
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country_Name    58 non-null     object
#  1   Code            58 non-null     object
#  2   Country Name    54 non-null     object
#  3   Indicator Name  54 non-null     object
#  4   2000            54 non-null     float64
#  5   2001            54 non-null     float64
#  6   2002            54 non-null     float64
#  7   2003            54 non-null     float64
#  8   2004            54 non-null     float64
#  9   2005            54 non-null     float64
#  10  2006            54 non-null     float64
#  11  2007            54 non-null     float64
#  12  2008            54 non-null     float64
#  13  2009            54 non-null     float64
#  14  2010            54 non-null     float64
#  15  2011            54 non-null     float64
#  16  2012            54 non-null     float64
#  17  2013            54 non-null     float64
#  18  2014            54 non-null     float64
#  19  2015            54 non-null     float64
#  20  2016            54 non-null     float64
#  21  2017            54 non-null     float64
#  22  2018            54 non-null     float64
#  23  2019            54 non-null     float64
# dtypes: float64(20), object(4)
# memory usage: 11.3+ KB

# %%
afr_che.drop(columns=['Country Name', 'Indicator Name'], axis=1, inplace=True)

# %%
afr_che.drop(10, inplace=True)

# %% [markdown]
# ### Summary of the cleaned data set
#
# Clean data set were grouped according to the following:
#
# afr_age => dataframe shows the death by age category.
#
# afr_dt => dataframe shows the causes of death.
#
# afr_pop => dataframe shows the population growth in Africa.
#
# afr_doctors => dataframe shows the amount of doctors per 10,000 patient.
#
# afr_che => dataframe shows the African expenditure on health by %GDP.

# %% [markdown]
# ## INSIGHTS

# %%
afr_dt.head()
# Out:
#   Country_Name  Year Number of executions (Amnesty International)  Meningitis  \
# 0      Algeria  1990                                            0       838.0
# 1      Algeria  1991                                            0       794.0
# 2      Algeria  1992                                            0       763.0
# 3      Algeria  1993                                            0       736.0
# 4      Algeria  1994                                            0       708.0
#
#    Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                   1337.0                439.0
# 1                                   1411.0                451.0
# 2                                   1494.0                470.0
# 3                                   1582.0                488.0
# 4                                   1675.0                509.0
#
#    Nutritional deficiencies  Malaria  Drowning  Interpersonal violence  ...  \
# 0                     453.0      9.0    1207.0                   491.0  ...
# 1                     439.0      9.0    1136.0                   484.0  ...
# 2                     427.0     12.0    1111.0                   497.0  ...
# 3                     417.0     12.0    1092.0                   513.0  ...
# 4                     402.0      8.0    1086.0                   553.0  ...
#
#    Chronic kidney disease  Poisonings  Protein  Terrorism (deaths)  \
# 0                  3559.0       485.0    422.0                 3.0
# 1                  3640.0       469.0    408.0                42.0
# 2                  3687.0       464.0    396.0               236.0
# 3                  3741.0       461.0    386.0                 0.0
# 4                  3806.0       460.0    370.0               500.0
#
#    Road injuries  Chronic respiratory diseases  \
# 0        13438.0                        4410.0
# 1        13120.0                        4481.0
# 2        13115.0                        4571.0
# 3        13154.0                        4668.0
# 4        13326.0                        4773.0
#
#    Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                      2401.0              3981.0
# 1                                      2456.0              4033.0
# 2                                      2500.0              4083.0
# 3                                      2542.0              4136.0
# 4                                      2588.0              4193.0
#
#    Fire, heat, and hot substances  Acute hepatitis
# 0                          1113.0            486.0
# 1                          1078.0            478.0
# 2                          1071.0            472.0
# 3                          1067.0            470.0
# 4                          1095.0            469.0
#
# [5 rows x 35 columns]

# %%
afr_dt['Total Death'] = afr_dt.sum(axis=1)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\3463311214.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   afr_dt['Total Death'] = afr_dt.sum(axis=1)

# %%
a_ct= afr_dt.drop("Year", axis=1, inplace=False)

# %%
a_yr = afr_dt.drop("Country_Name", axis=1, inplace=False)

# %%
a_ct
# Out:
#      Country_Name Number of executions (Amnesty International)  Meningitis  \
# 0         Algeria                                            0       838.0
# 1         Algeria                                            0       794.0
# 2         Algeria                                            0       763.0
# 3         Algeria                                            0       736.0
# 4         Algeria                                            0       708.0
# ...           ...                                          ...         ...
# 1617       Zambia                                            0      2256.0
# 1618       Zambia                                            0      2174.0
# 1619       Zambia                                            0      2156.0
# 1620       Zambia                                            0      2088.0
# 1621       Zambia                                            0      2065.0
#
#       Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                      1337.0                439.0
# 1                                      1411.0                451.0
# 2                                      1494.0                470.0
# 3                                      1582.0                488.0
# 4                                      1675.0                509.0
# ...                                       ...                  ...
# 1617                                    626.0                173.0
# 1618                                    651.0                178.0
# 1619                                    689.0                186.0
# 1620                                    726.0                195.0
# 1621                                    763.0                203.0
#
#       Nutritional deficiencies  Malaria  Drowning  Interpersonal violence  \
# 0                        453.0      9.0    1207.0                   491.0
# 1                        439.0      9.0    1136.0                   484.0
# 2                        427.0     12.0    1111.0                   497.0
# 3                        417.0     12.0    1092.0                   513.0
# 4                        402.0      8.0    1086.0                   553.0
# ...                        ...      ...       ...                     ...
# 1617                    2269.0   5235.0     406.0                  1428.0
# 1618                    2148.0   4716.0     391.0                  1490.0
# 1619                    2087.0   4287.0     386.0                  1531.0
# 1620                    1954.0   4815.0     366.0                  1577.0
# 1621                    1899.0   4777.0     359.0                  1616.0
#
#       Maternal disorders  ...  Poisonings  Protein  Terrorism (deaths)  \
# 0                 1634.0  ...       485.0    422.0                 3.0
# 1                 1541.0  ...       469.0    408.0                42.0
# 2                 1482.0  ...       464.0    396.0               236.0
# 3                 1422.0  ...       461.0    386.0                 0.0
# 4                 1356.0  ...       460.0    370.0               500.0
# ...                  ...  ...         ...      ...                 ...
# 1617               815.0  ...       305.0   2199.0                 0.0
# 1618               816.0  ...       304.0   2078.0                 0.0
# 1619               815.0  ...       307.0   2016.0                 0.0
# 1620               804.0  ...       306.0   1884.0                 0.0
# 1621               804.0  ...       309.0   1828.0                 0.0
#
#       Road injuries  Chronic respiratory diseases  \
# 0           13438.0                        4410.0
# 1           13120.0                        4481.0
# 2           13115.0                        4571.0
# 3           13154.0                        4668.0
# 4           13326.0                        4773.0
# ...             ...                           ...
# 1617         2173.0                        2214.0
# 1618         2209.0                        2249.0
# 1619         2252.0                        2302.0
# 1620         2258.0                        2341.0
# 1621         2285.0                        2388.0
#
#       Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                         2401.0              3981.0
# 1                                         2456.0              4033.0
# 2                                         2500.0              4083.0
# 3                                         2542.0              4136.0
# 4                                         2588.0              4193.0
# ...                                          ...                 ...
# 1617                                      4026.0              5804.0
# 1618                                      4179.0              6000.0
# 1619                                      4386.0              6275.0
# 1620                                      4481.0              6385.0
# 1621                                      4593.0              6528.0
#
#       Fire, heat, and hot substances  Acute hepatitis  Total Death
# 0                             1113.0            486.0     136135.0
# 1                             1078.0            478.0     136294.0
# 2                             1071.0            472.0     137749.0
# 3                             1067.0            470.0     138894.0
# 4                             1095.0            469.0     142531.0
# ...                              ...              ...          ...
# 1617                           326.0            270.0     122604.0
# 1618                           323.0            268.0     122496.0
# 1619                           325.0            270.0     123417.0
# 1620                           323.0            265.0     122568.0
# 1621                           326.0            263.0     122020.0
#
# [1622 rows x 35 columns]

# %%
a_ct.query("Country_Name != 'Western Sahara'", inplace=True)

# %%
a_ct.head()
# Out:
#   Country_Name Number of executions (Amnesty International)  Meningitis  \
# 0      Algeria                                            0       838.0
# 1      Algeria                                            0       794.0
# 2      Algeria                                            0       763.0
# 3      Algeria                                            0       736.0
# 4      Algeria                                            0       708.0
#
#    Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                   1337.0                439.0
# 1                                   1411.0                451.0
# 2                                   1494.0                470.0
# 3                                   1582.0                488.0
# 4                                   1675.0                509.0
#
#    Nutritional deficiencies  Malaria  Drowning  Interpersonal violence  \
# 0                     453.0      9.0    1207.0                   491.0
# 1                     439.0      9.0    1136.0                   484.0
# 2                     427.0     12.0    1111.0                   497.0
# 3                     417.0     12.0    1092.0                   513.0
# 4                     402.0      8.0    1086.0                   553.0
#
#    Maternal disorders  ...  Poisonings  Protein  Terrorism (deaths)  \
# 0              1634.0  ...       485.0    422.0                 3.0
# 1              1541.0  ...       469.0    408.0                42.0
# 2              1482.0  ...       464.0    396.0               236.0
# 3              1422.0  ...       461.0    386.0                 0.0
# 4              1356.0  ...       460.0    370.0               500.0
#
#    Road injuries  Chronic respiratory diseases  \
# 0        13438.0                        4410.0
# 1        13120.0                        4481.0
# 2        13115.0                        4571.0
# 3        13154.0                        4668.0
# 4        13326.0                        4773.0
#
#    Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                      2401.0              3981.0
# 1                                      2456.0              4033.0
# 2                                      2500.0              4083.0
# 3                                      2542.0              4136.0
# 4                                      2588.0              4193.0
#
#    Fire, heat, and hot substances  Acute hepatitis  Total Death
# 0                          1113.0            486.0     136135.0
# 1                          1078.0            478.0     136294.0
# 2                          1071.0            472.0     137749.0
# 3                          1067.0            470.0     138894.0
# 4                          1095.0            469.0     142531.0
#
# [5 rows x 35 columns]

# %%
a_yr.head(3)
# Out:
#    Year Number of executions (Amnesty International)  Meningitis  \
# 0  1990                                            0       838.0
# 1  1991                                            0       794.0
# 2  1992                                            0       763.0
#
#    Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                   1337.0                439.0
# 1                                   1411.0                451.0
# 2                                   1494.0                470.0
#
#    Nutritional deficiencies  Malaria  Drowning  Interpersonal violence  \
# 0                     453.0      9.0    1207.0                   491.0
# 1                     439.0      9.0    1136.0                   484.0
# 2                     427.0     12.0    1111.0                   497.0
#
#    Maternal disorders  ...  Poisonings  Protein  Terrorism (deaths)  \
# 0              1634.0  ...       485.0    422.0                 3.0
# 1              1541.0  ...       469.0    408.0                42.0
# 2              1482.0  ...       464.0    396.0               236.0
#
#    Road injuries  Chronic respiratory diseases  \
# 0        13438.0                        4410.0
# 1        13120.0                        4481.0
# 2        13115.0                        4571.0
#
#    Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                      2401.0              3981.0
# 1                                      2456.0              4033.0
# 2                                      2500.0              4083.0
#
#    Fire, heat, and hot substances  Acute hepatitis  Total Death
# 0                          1113.0            486.0     136135.0
# 1                          1078.0            478.0     136294.0
# 2                          1071.0            472.0     137749.0
#
# [3 rows x 35 columns]

# %%
a_yr_new= a_yr.groupby('Year').sum()

# %%
a_yr_new.plot(kind='line', y='Total Death')
plt.title('Total Deaths in Africa from 1990 to 2019')
plt.ylabel('Total Death Count')
plt.yscale('log');

# %% [markdown]
# In the above, the data showed a spike in deaths from 1990 to 1994, followed by a steep decline from 1995 to 1996 before a sharp rise to a peak of 2005. This gradually dropped all the way to 2019.

# %%
a_ct_new =a_ct.groupby("Country_Name").sum()

# %%
a_ct_new.head()
# Out:
#               Meningitis  Alzheimer's disease and other dementias  \
# Country_Name
# Algeria          15685.0                                  86914.0
# Angola          110893.0                                  17704.0
# Benin            69978.0                                  13464.0
# Botswana          3835.0                                   2887.0
# Burkina Faso    175973.0                                  25070.0
#
#               Parkinson's disease  Nutritional deficiencies   Malaria  \
# Country_Name
# Algeria                   22943.0                    7138.0      70.0
# Angola                     4486.0                  235181.0  317069.0
# Benin                      3804.0                   44748.0  316834.0
# Botswana                    807.0                    5394.0     662.0
# Burkina Faso               6915.0                  140980.0  950762.0
#
#               Drowning  Interpersonal violence  Maternal disorders  HIV/AIDS  \
# Country_Name
# Algeria        24273.0                 16702.0             29475.0    6101.0
# Angola         34337.0                 20795.0             61545.0  244358.0
# Benin          11517.0                 16162.0             34853.0   80892.0
# Botswana        2607.0                  9718.0              2068.0  263306.0
# Burkina Faso   19688.0                 37008.0             46191.0  333448.0
#
#               Drug use disorders  ...  Poisonings   Protein  \
# Country_Name                      ...
# Algeria                  10612.0  ...     12337.0    6407.0
# Angola                    1190.0  ...     14022.0  229863.0
# Benin                      261.0  ...      5654.0   43399.0
# Botswana                   173.0  ...      1091.0    5265.0
# Burkina Faso               870.0  ...     13499.0  135194.0
#
#               Terrorism (deaths)  Road injuries  Chronic respiratory diseases  \
# Country_Name
# Algeria                  11066.0       369395.0                      168453.0
# Angola                    2195.0       241350.0                      101847.0
# Benin                        0.0        45197.0                       44797.0
# Botswana                     6.0        15000.0                       18118.0
# Burkina Faso               133.0       102398.0                       60148.0
#
#               Cirrhosis and other chronic liver diseases  Digestive diseases  \
# Country_Name
# Algeria                                          91927.0            146527.0
# Angola                                          119381.0            190974.0
# Benin                                            46718.0             79638.0
# Botswana                                         10592.0             20318.0
# Burkina Faso                                     77027.0            142102.0
#
#               Fire, heat, and hot substances  Acute hepatitis  Total Death
# Country_Name
# Algeria                              27628.0          10492.0    4672406.0
# Angola                               15712.0          14431.0    5429048.0
# Benin                                 7791.0           6281.0    2230478.0
# Botswana                              2748.0            325.0     712200.0
# Burkina Faso                         15183.0           8774.0    4929536.0
#
# [5 rows x 33 columns]

# %%
ax= a_ct_new.sort_values('Total Death', ascending=False)

# %%
ax.plot(kind='bar', y='Total Death', figsize=[10, 5], color='red')
plt.title('Total Death by African Countries from 1990 to 2019')
plt.xlabel('Country')
plt.ylabel('Total Death Count')
plt.yscale('log');

# %% [markdown]
# The first five bars represents the top five highest death count by country. The data reveals that Seychelles had the lowest death rate and Nigeria accounting for the highest.

# %%
afr_age.head()
# Out:
#   Country_Name  Year  Deaths 70+ years  Deaths 50-69 years  \
# 0      Algeria  1990             45295               28519
# 1      Algeria  1991             46269               29803
# 2      Algeria  1992             47879               30238
# 3      Algeria  1993             49385               30771
# 4      Algeria  1994             51193               31202
#
#    Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 0                    26069               7856           45891
# 1                    25786               7224           43714
# 2                    26364               7056           41813
# 3                    26955               6899           40063
# 4                    28917               6923           38320

# %%
afr_age_df = afr_age.groupby('Year').sum()

# %%
afr_age_df.plot(kind='bar', stacked=True, figsize=[10,6])
plt.title('Deaths by Age Category from 1990 to 2019')
plt.ylabel('Count of Deaths')
plt.yscale('log');

# %% [markdown]
# In all five age groups, we can see a pattern in death population across 1990 to 2019. The death toll for persons above 50 years increased gradually over the years. That of group 15-49 years witnessed a gentle rise and fall in death population. The death toll for the 5-14 years groups are associated with a gentle rise from 1990 with a spike in 1994, then declining the next year with a gentle rise up until 2004 where it remained relatively fixed till 2013 and increased further from there. The under 5 years groups had a gentle rise from 1990, reaching a peak at 2004 and then falling gradually.

# %%
afr_age_df1 = afr_age.drop('Year', axis=1, inplace=False)

# %%
afr_age_df2 = afr_age_df1.groupby('Country_Name').sum()

# %%
afr_age_df2.plot(kind='bar', stacked=True, figsize=[10,7])
plt.title('Deaths by Age by Country')
plt.ylabel('Count')
plt.xlabel('Country')
plt.yscale('log');

# %% [markdown]
# The data set clearly shows that persons who were aged 70 and above died more in Africa as compared to other aged groups.

# %%
afr_pop_df = afr_pop[afr_pop['Year'] < 2020]

# %%
ax=afr_pop_df.sort_values('Population', ascending=False)

# %%
plt.figure(figsize=[15,10])

plt.subplot(3,1,1)

afr_pop_df.groupby('Country_Name')['Population'].sum().plot(kind='bar')
plt.title('Total Population Growth by Country from 1990 to 2019')
plt.xlabel('Country')
plt.ylabel('Population')
plt.yscale('log')

plt.subplot(3,1,3)

afr_pop_df.groupby('Year')['Population'].sum().plot(kind='bar')
plt.title('Population Growth in Africa from 1990 to 2019')
plt.ylabel('Population')
plt.yscale('log');

# %% [markdown]
# The fisrt chart shows the total population growth by country from 1990 to 2019.
#
# The second chart shows the population growth in Africa from 1990 to 2019.

# %%
afr_doctors.head()
# Out:
#   Location  Period  Value
# 0   Angola    2018   2.14
# 1   Angola    2017   2.15
# 2   Angola    2009   1.31
# 3   Angola    2004   0.62
# 4   Angola    1997   0.59

# %%
mx =afr_doctors.groupby('Location')['Value'].mean().max()
mn =afr_doctors.groupby('Location')['Value'].mean().min()

# %%
#Doctors per 10,000 persons
tick=np.arange(20, mx+500, 2000)

plt.figure(figsize=[8,5])
afr_doctors.groupby('Location')['Value'].mean().plot(kind='bar')
plt.title('Average Number of Doctors by Location from 1990 to 2019')
plt.ylabel('Count')
plt.yticks(tick, tick);

# %% [markdown]
# The average number of doctors in this chart shows that Nigeria has had the highest with an average of 35,000 doctors per year.

# %%
#Health expenditure by %GDP
afr_che.head()
# Out:
#   Country_Name Code      2000      2001      2002      2003      2004  \
# 0      Algeria  DZA  3.489033  3.837877  3.730042  3.601041  3.544073
# 1       Angola  AGO  1.908599  4.483516  3.329461  3.547973  3.967201
# 2     Botswana  BWA  5.827264  6.156716  6.421541  6.176169  5.795304
# 3      Burundi  BDI  6.176971  6.404844  6.472161  6.313277  7.701042
# 4     Cameroon  CMR  4.297622  4.097513  4.294797  4.268264  4.015150
#
#        2005      2006       2007  ...       2010       2011      2012  \
# 0  3.235161  3.355102   3.821416  ...   5.117172   5.267481  6.000510
# 1  2.852197  2.685537   2.974388  ...   2.695100   2.645608  2.395750
# 2  5.025351  4.773733   5.333117  ...   6.194025   5.776903  6.141460
# 3  8.423713  9.942323  10.580819  ...  11.276376  10.069978  8.526685
# 4  4.095445  4.028973   3.959409  ...   3.758915   4.016860  4.073135
#
#        2013      2014      2015      2016      2017      2018      2019
# 0  6.035763  6.547214  6.978489  6.607496  6.279384  6.163026  6.243371
# 1  2.732828  2.434129  2.605795  2.713149  2.791503  2.540102  2.533360
# 2  6.224388  5.597931  5.726299  5.560522  6.134534  5.968672  6.048366
# 3  8.537285  7.315492  6.428827  7.719209  7.903018  8.244769  7.990914
# 4  3.784994  3.951177  3.748792  3.729508  3.492165  3.465106  3.595395
#
# [5 rows x 22 columns]

# %%
afr_che_df = afr_che.drop('Code', axis=1, inplace=False)

# %%
afr_che_df.dropna(inplace=True)

# %%
total_mean= afr_che_df.mean(axis=1)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\1804233478.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total_mean= afr_che_df.mean(axis=1)

# %%
afr_che_df['Mean']=total_mean

# %%
afr_che_df.head()
# Out:
#   Country_Name      2000      2001      2002      2003      2004      2005  \
# 0      Algeria  3.489033  3.837877  3.730042  3.601041  3.544073  3.235161
# 1       Angola  1.908599  4.483516  3.329461  3.547973  3.967201  2.852197
# 2     Botswana  5.827264  6.156716  6.421541  6.176169  5.795304  5.025351
# 3      Burundi  6.176971  6.404844  6.472161  6.313277  7.701042  8.423713
# 4     Cameroon  4.297622  4.097513  4.294797  4.268264  4.015150  4.095445
#
#        2006       2007      2008  ...       2011      2012      2013  \
# 0  3.355102   3.821416  4.201884  ...   5.267481  6.000510  6.035763
# 1  2.685537   2.974388  3.322905  ...   2.645608  2.395750  2.732828
# 2  4.773733   5.333117  5.782003  ...   5.776903  6.141460  6.224388
# 3  9.942323  10.580819  9.235422  ...  10.069978  8.526685  8.537285
# 4  4.028973   3.959409  3.822916  ...   4.016860  4.073135  3.784994
#
#        2014      2015      2016      2017      2018      2019      Mean
# 0  6.547214  6.978489  6.607496  6.279384  6.163026  6.243371  4.970746
# 1  2.434129  2.605795  2.713149  2.791503  2.540102  2.533360  2.950085
# 2  5.597931  5.726299  5.560522  6.134534  5.968672  6.048366  5.859465
# 3  7.315492  6.428827  7.719209  7.903018  8.244769  7.990914  8.280667
# 4  3.951177  3.748792  3.729508  3.492165  3.465106  3.595395  3.911774
#
# [5 rows x 22 columns]

# %%
ax = afr_che_df.loc[:,['Country_Name','Mean']].sort_values('Mean', ascending=False)

plt.figure(figsize=[10,5])

sb.barplot(data=ax, x='Country_Name', y='Mean', color='green')

plt.title('Country\'s Health Expenditure by % GDP from 1990 to 2019')
plt.xlabel('Country')
plt.ylabel('Health Expenditure by % GDP (avg)')
plt.xticks(rotation= 90);

# %% [markdown]
# From the data above, we can clearly see that Sierra Leone has spent more on health in terms of comparison with their GDP followed by Namibia. The country with the least is South Sudan. Somalia has no records owing to the tension in the area.

# %%
ax = afr_dt.drop(["Country_Name", "Year", "Total Death"], axis=1, inplace=False)

# %%
ax_df= ax.sum().sort_values(ascending=False)
# Out:
# C:\Users\UG\AppData\Local\Temp\ipykernel_5608\3707141258.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ax_df= ax.sum().sort_values(ascending=False)

# %%
plt.figure(figsize=[10,6])

ax_df.plot(kind='bar', color='red')
plt.xlabel('Causes of Death')
plt.ylabel('Count')
plt.title('Total Death Count by Causes')
plt.yscale('log')
plt.xticks(rotation=90);

# %% [markdown]
# The chart shows the prevalent causes of death in Africa. A greater population is likely to die by cardiovascular diseases, HIV/AIDS, diarrheal diseases, etc. Fewer than 100,000 died by the forces of nature.

# %% [markdown]
# ### Paired relationship

# %%
#avg death by year to avg health expenditure by %GDP by year

# %%
afr_dt.head()
# Out:
#   Country_Name  Year Number of executions (Amnesty International)  Meningitis  \
# 0      Algeria  1990                                            0       838.0
# 1      Algeria  1991                                            0       794.0
# 2      Algeria  1992                                            0       763.0
# 3      Algeria  1993                                            0       736.0
# 4      Algeria  1994                                            0       708.0
#
#    Alzheimer's disease and other dementias  Parkinson's disease  \
# 0                                   1337.0                439.0
# 1                                   1411.0                451.0
# 2                                   1494.0                470.0
# 3                                   1582.0                488.0
# 4                                   1675.0                509.0
#
#    Nutritional deficiencies  Malaria  Drowning  Interpersonal violence  ...  \
# 0                     453.0      9.0    1207.0                   491.0  ...
# 1                     439.0      9.0    1136.0                   484.0  ...
# 2                     427.0     12.0    1111.0                   497.0  ...
# 3                     417.0     12.0    1092.0                   513.0  ...
# 4                     402.0      8.0    1086.0                   553.0  ...
#
#    Poisonings  Protein  Terrorism (deaths)  Road injuries  \
# 0       485.0    422.0                 3.0        13438.0
# 1       469.0    408.0                42.0        13120.0
# 2       464.0    396.0               236.0        13115.0
# 3       461.0    386.0                 0.0        13154.0
# 4       460.0    370.0               500.0        13326.0
#
#    Chronic respiratory diseases  Cirrhosis and other chronic liver diseases  \
# 0                        4410.0                                      2401.0
# 1                        4481.0                                      2456.0
# 2                        4571.0                                      2500.0
# 3                        4668.0                                      2542.0
# 4                        4773.0                                      2588.0
#
#    Digestive diseases  Fire, heat, and hot substances  Acute hepatitis  \
# 0              3981.0                          1113.0            486.0
# 1              4033.0                          1078.0            478.0
# 2              4083.0                          1071.0            472.0
# 3              4136.0                          1067.0            470.0
# 4              4193.0                          1095.0            469.0
#
#    Total Death
# 0     136135.0
# 1     136294.0
# 2     137749.0
# 3     138894.0
# 4     142531.0
#
# [5 rows x 36 columns]

# %%
avg_dt = afr_dt.groupby('Year').mean()

# %%
mdx=avg_dt.drop(avg_dt.iloc[:,:32], axis=1, inplace=False)

# %%
mdx.head()
# Out:
#         Total Death
# Year
# 1990  133993.500000
# 1991  136532.777778
# 1992  136936.945455
# 1993  142889.944444
# 1994  156473.777778

# %%
chx =afr_che_df.iloc[:,1:21]

# %%
chx.head()
# Out:
#        2000      2001      2002      2003      2004      2005      2006  \
# 0  3.489033  3.837877  3.730042  3.601041  3.544073  3.235161  3.355102
# 1  1.908599  4.483516  3.329461  3.547973  3.967201  2.852197  2.685537
# 2  5.827264  6.156716  6.421541  6.176169  5.795304  5.025351  4.773733
# 3  6.176971  6.404844  6.472161  6.313277  7.701042  8.423713  9.942323
# 4  4.297622  4.097513  4.294797  4.268264  4.015150  4.095445  4.028973
#
#         2007      2008       2009       2010       2011      2012      2013  \
# 0   3.821416  4.201884   5.359395   5.117172   5.267481  6.000510  6.035763
# 1   2.974388  3.322905   3.842609   2.695100   2.645608  2.395750  2.732828
# 2   5.333117  5.782003   6.525008   6.194025   5.776903  6.141460  6.224388
# 3  10.580819  9.235422  10.350219  11.276376  10.069978  8.526685  8.537285
# 4   3.959409  3.822916   3.739336   3.758915   4.016860  4.073135  3.784994
#
#        2014      2015      2016      2017      2018      2019
# 0  6.547214  6.978489  6.607496  6.279384  6.163026  6.243371
# 1  2.434129  2.605795  2.713149  2.791503  2.540102  2.533360
# 2  5.597931  5.726299  5.560522  6.134534  5.968672  6.048366
# 3  7.315492  6.428827  7.719209  7.903018  8.244769  7.990914
# 4  3.951177  3.748792  3.729508  3.492165  3.465106  3.595395

# %%
chxx=afr_che_df.melt(id_vars='Country_Name', value_vars=chx, var_name='Year', value_name='Health exp by %GDP')

# %%
che_avg=chxx.groupby('Year').mean()

# %%
chdr =mdx.merge(che_avg, how='left', left_index=True, right_index=True)

# %%
chdr.head(11)
# Out:
#         Total Death  Health exp by %GDP
# Year
# 1990  133993.500000                 NaN
# 1991  136532.777778                 NaN
# 1992  136936.945455                 NaN
# 1993  142889.944444                 NaN
# 1994  156473.777778                 NaN
# 1995  150627.277778                 NaN
# 1996  155165.833333                 NaN
# 1997  159336.629630                 NaN
# 1998  163024.777778                 NaN
# 1999  166538.240741                 NaN
# 2000  168981.166667            4.454306

# %%
sb.scatterplot(data=chdr, y='Total Death', x='Health exp by %GDP', )
plt.title('Death Count to Heath Expediture by %GDP from 1990 to 2019')
plt.ylabel('Death by year (avg)')
plt.xlabel('Health Expediture by %GDP by year (avg)');

# %% [markdown]
# The chart shows that as the health expenditure increased, the death count reduced.

# %% [markdown]
# ## RECOMMENDATION
#
# From the insights generated, I can recommend that:
#
# 1. Africa needs to have an efficient plan to take care of its elderly.
# 2. Increase spending in the health sector.
# 3. Employ more doctors especially in countries with a higher population.
# 4. Set up measures to tackle cardiovascular diseases, HIV/AIDS, diarrheal, etc.
